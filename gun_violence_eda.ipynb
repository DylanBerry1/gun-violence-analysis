# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd

# %%
df = dd.read_csv('Crimes_-_2001_to_Present_20260213.csv', assume_missing=True, dtype={'IUCR': 'object', 'Beat': 'object', 'District': 'object'})
result = df[df['Description'].str.contains('GUN|FIREARM', na=False)].compute()

# %%
result
# Out:
#                 ID Case Number                    Date                 Block  \
# 14      14101986.0    JK138833  02/04/2026 11:15:00 PM    084XX S PULASKI RD
# 15      14101987.0    JK138794  02/04/2026 11:14:00 PM  135XX S BRAINARD AVE
# 30      14101934.0    JK138770  02/04/2026 10:10:00 PM       0000X E 75TH ST
# 46      14101877.0    JK138740  02/04/2026 09:31:00 PM      006XX E 111TH ST
# 55      14101906.0    JK138738  02/04/2026 09:19:00 PM  038XX W ROOSEVELT RD
# ...            ...         ...                     ...                   ...
# 245507   1310050.0     G000119  01/01/2001 12:15:00 AM         019XX W 21 ST
# 245515   1311859.0     G000175  01/01/2001 12:05:00 AM       064XX S LOWE AV
# 245520   1315137.0     G000126  01/01/2001 12:05:00 AM         037XX W 83 PL
# 245523   1327014.0     G000132  01/01/2001 12:05:00 AM      130XX S ELLIS AV
# 245526   1320836.0     G000062  01/01/2001 12:04:00 AM   008XX N LECLAIRE AV
#
# ...
